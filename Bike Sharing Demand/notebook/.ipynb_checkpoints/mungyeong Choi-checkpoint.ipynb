# %% [markdown]
# # 1/11/2019(금)

# %%
import pandas as pd

# %%
train = pd.read_csv("../data/train.csv", parse_dates=["datetime"])
train.shape
# Out:
# (10886, 12)

# %%
train.head()
# count(1시간 동안 총 임대 수) = casual(등록되지 않은 사용자의 임대 수) + registered(등록된 사용자의 임대 수)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train.tail()
# 사용 데이터는 2011년 1월 1일부터 2012년 12월 19일 까지 있음
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %% [markdown]
# ### year, month, day 열 추가

# %%
train['year'] = train.datetime.dt.year
train['month'] = train.datetime.dt.month
train['day'] = train.datetime.dt.day
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day
# 0        81        0.0       3          13     16  2011      1    1
# 1        80        0.0       8          32     40  2011      1    1
# 2        80        0.0       5          27     32  2011      1    1
# 3        75        0.0       3          10     13  2011      1    1
# 4        75        0.0       0           1      1  2011      1    1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train.year.value_counts()
# Out:
# 2012    5464
# 2011    5422
# Name: year, dtype: int64

# %% [markdown]
# # 1/16/2019(수)

# %%
train.year.plot()

# %%
import seaborn as sns

# %%
sns.barplot(x="year", y="count", data=train)

# %% [markdown]
# ## 연도별, 월별, 일별 대여량 비교해보기

# %%
fig = plt.figure()

# %%
axe1 = fig.add_subplot(131)
axe2 = fig.add_subplot(132)
axe3 = fig.add_subplot(133)

fig

# %%
sns.barplot(data = train, x="year", y="count", ax=axe1)
sns.barplot(data = train, x="month", y="count", ax=axe2)
sns.barplot(data = train, x="day", y="count", ax=axe3)

fig.set_size_inches(15,4)

axe1.set_title("연도별 대여량")

fig

# %% [markdown]
# ## 한글 깨짐 방지

# %%
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)

# %% [markdown]
# ## 좀 더 빠르게 그래프 그리기
# ### 그래프를 그려본 결과 11년도 보다 12년도에 대여량이 많아졌고
# ### 5 ~ 10월에 대여량이 가장 많고
# ### 일별 대여량은 거의 비슷하다는 것을 알 수 있다.

# %%
figure, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3)
figure.set_size_inches(15,4)

sns.barplot(data=train, x="year", y="count", ax=ax1)
sns.barplot(data=train, x="month", y="count", ax=ax2)
sns.barplot(data=train, x="day", y="count", ax=ax3)

ax1.set(ylabel='Count',title="연도별 대여량")
ax2.set(xlabel='month',title="월별 대여량")
ax3.set(xlabel='day', title="일별 대여량")
# Out:
# [Text(0.5,0,'day'), Text(0.5,1,'일별 대여량')]

# %%
test = pd.read_csv("../data/test.csv")

# %%
test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day
# 0        81        0.0       3          13     16  2011      1    1
# 1        80        0.0       8          32     40  2011      1    1
# 2        80        0.0       5          27     32  2011      1    1
# 3        75        0.0       3          10     13  2011      1    1
# 4        75        0.0       0           1      1  2011      1    1

# %%
train.shape
# Out:
# (10886, 15)

# %%
test.shape
# Out:
# (6493, 9)

# %%
test.tail()
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 6488  2012-12-31 19:00:00       1        0           1        2  10.66
# 6489  2012-12-31 20:00:00       1        0           1        2  10.66
# 6490  2012-12-31 21:00:00       1        0           1        1  10.66
# 6491  2012-12-31 22:00:00       1        0           1        1  10.66
# 6492  2012-12-31 23:00:00       1        0           1        1  10.66
#
#        atemp  humidity  windspeed
# 6488  12.880        60    11.0014
# 6489  12.880        60    11.0014
# 6490  12.880        60    11.0014
# 6491  13.635        56     8.9981
# 6492  13.635        65     8.9981

# %%
train.tail()
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# 10881  19.695        50    26.0027       7         329    336  2012     12
# 10882  17.425        57    15.0013      10         231    241  2012     12
# 10883  15.910        61    15.0013       4         164    168  2012     12
# 10884  17.425        61     6.0032      12         117    129  2012     12
# 10885  16.665        66     8.9981       4          84     88  2012     12
#
#        day
# 10881   19
# 10882   19
# 10883   19
# 10884   19
# 10885   19

# %% [markdown]
# ## dayofweek추가 (0~6 순서대로 월~일)

# %%
train["dayofweek"] = train["datetime"].dt.dayofweek
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  dayofweek
# 0        81        0.0       3          13     16  2011      1    1          5
# 1        80        0.0       8          32     40  2011      1    1          5
# 2        80        0.0       5          27     32  2011      1    1          5
# 3        75        0.0       3          10     13  2011      1    1          5
# 4        75        0.0       0           1      1  2011      1    1          5

# %%
train.shape
# Out:
# (10886, 16)

# %%
train["hour"] = train['datetime'].dt.hour
train["minute"] = train['datetime'].dt.minute
train['second'] = train['datetime'].dt.second

# %%
train["dayofweek"].value_counts()
# Out:
# 5    1584
# 6    1579
# 3    1553
# 2    1551
# 0    1551
# 1    1539
# 4    1529
# Name: dayofweek, dtype: int64

# %% [markdown]
# ## pointplot으로 계절별, 날씨별, 일별, 평일과 주말별로 그래프 그리기
#
# ### 일할 때는 출퇴근 시간에 대여량이 많고 그렇지 않을 때는 낮시간에 많다.

# %%
fig,(ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=5)
fig.set_size_inches(18, 25)

sns.pointplot(data = train, x="hour", y="count", ax=ax1)

sns.pointplot(data = train, x="hour", y="count", hue="workingday", ax=ax2)

sns.pointplot(data = train, x="hour", y="count", hue="dayofweek", ax=ax3)

sns.pointplot(data = train, x="hour", y="count", hue="weather", ax=ax4)

sns.pointplot(data = train, x="hour", y="count", hue="season", ax=ax5)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.set_size_inches(12, 5)
sns.regplot(data=train, x="temp", y="count", ax=ax1)
sns.regplot(data=train, x="windspeed", y="count", ax=ax2)
sns.regplot(data=train, x="humidity", y="count", ax=ax3)

# %%
def concatenate_year_month(datetime):
    return "{}-{}".format(datetime.year, datetime.month)

train["year_month"] = train['datetime'].apply(concatenate_year_month)

print(train.shape)
train[["datetime", "year_month"]].head()
# Out:
# (10886, 20)
#              datetime year_month
# 0 2011-01-01 00:00:00     2011-1
# 1 2011-01-01 01:00:00     2011-1
# 2 2011-01-01 02:00:00     2011-1
# 3 2011-01-01 03:00:00     2011-1
# 4 2011-01-01 04:00:00     2011-1

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
fig.set_size_inches(18, 4)

sns.barplot(data=train, x='year', y='count', ax=ax1)
sns.barplot(data=train, x='month', y='count', ax=ax2)

fig, ax3 = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(18, 4)

sns.barplot(data=train, x='year_month', y='count', ax=ax3)

# %% [markdown]
# 1. 2011년보다 2012년의 대여량이 더 많다.
# 2. 겨울 < 여름
# 3. 2011년과 2012년의 월별 데이터를 이어보면 전체적으로 증가하는 추세이다.

# %% [markdown]
# ## ??? trainwithoutOutliers

# %%
import numpy as np
trainwithoutOutliers = train[np.abs(train["count"] - train["count"].mean()) <= (3*train["count"].std())]

print(train.shape)
print(trainwithoutOutliers.shape)
# Out:
# (10886, 20)
# (10739, 20)

# %%
from scipy import stats
figure, axes = plt.subplots(ncols=2, nrows=2)
figure.set_size_inches(12, 10)

sns.distplot(train["count"], ax = axes[0][0])
stats.probplot(train['count'], dist='norm', fit=True, plot=axes[0][1])
sns.distplot(np.log(trainwithoutOutliers['count']), ax=axes[1][0])
stats.probplot(np.log1p(trainwithoutOutliers['count']), dist='norm', fit=True, plot=axes[1][1])
# Out:
# ((array([-3.82819677, -3.60401975, -3.48099008, ...,  3.48099008,
#           3.60401975,  3.82819677]),
#   array([0.69314718, 0.69314718, 0.69314718, ..., 6.5971457 , 6.59850903,
#          6.5998705 ])),
#  (1.3486990121229776, 4.562423868087808, 0.9581176780909612))
